# %% [markdown]
# <a href="https://colab.research.google.com/github/MarManja/SP/blob/main/Extracci%C3%B3n_de_carcater%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde el equipo
from google.colab import files
files.upload()

# %%
#¢Convertir en detaframe
data=pd.read_csv("PROCESADO_Recoleccion_de_datos_Negocios_IN1002B (1).csv")
data.head(5)

# %%
#Verificamos información del DataFrame
data.info()

# %% [markdown]
# **Selección de variables categóricas (10)**

# %%
#Filtro por columnas no consecutivas
categoricas=data.iloc[ : ,[4,9,10,11,13,14,15,17,18,20,21,32,33]]
categoricas

# %%
#Verificamos información del nuevo DataFrame
categoricas.info()

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(categoricas)

# %%
#Verificamos información del nuevo DataFrame
categoricas1=categoricas.iloc[ : ,[7]]
categoricas1

# %% [markdown]
# Tabla 1

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(categoricas['Grupo al cual pertenece'])
table1

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('Grupo al cual pertenece')
Filtro_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('Grupo al cual pertenece los entrevistadores')
plt.ylabel('Frecuencia')

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")

# %% [markdown]
# Tabla 2

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(categoricas['Tipo de negocio'])
table2

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table2[table2['frequency']>9]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro2_index= Filtro2.set_index('Tipo de negocio')
Filtro2_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro2_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro2_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')

# %% [markdown]
# Tabla 3

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(categoricas['Rol de la persona entrevistada'])
table3

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro3= table3[table3['frequency']>1]
Filtro3

# %%
#Ajusto el indice de mi dataframe
Filtro3_index= Filtro3.set_index('Rol de la persona entrevistada')
Filtro3_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro3_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro3_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')

# %% [markdown]
# Tabla 4

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(categoricas['Antiguedad del negocio'])
table4

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro4= table4[table4['frequency']>1]
Filtro4

# %%
#Ajusto el indice de mi dataframe
Filtro4_index= Filtro4.set_index('Antiguedad del negocio')
Filtro4_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro4_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')

# %% [markdown]
# Tabla 5

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(categoricas['En promedio ¿cada cuanto realiza pedidos a sus proveedores o compra sus productos? (Use la cifra más cercana)'])
table5

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro5= table5[table5['frequency']>10]
Filtro5

# %%
#Ajusto el indice de mi dataframe
Filtro5_index= Filtro5.set_index('En promedio ¿cada cuanto realiza pedidos a sus proveedores o compra sus productos? (Use la cifra más cercana)')
Filtro5_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro5_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro5_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')

# %% [markdown]
# Tabla 6

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table6= freq_tbl(categoricas['¿Qué forma de pago permite a sus clientes?'])
table6

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro6= table6[table6['frequency']>2]
Filtro6

# %%
#Ajusto el indice de mi dataframe
Filtro6_index= Filtro6.set_index('¿Qué forma de pago permite a sus clientes?')
Filtro6_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro6_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro6_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Tabla 7

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(categoricas['¿Ha participado en algún plan de colaboración con otras tiendas o empresas? \n(por ejemplo, esfuerzos conjuntos de marketing, compras al por mayor, servicios de entrega compartidos)'])
table7

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>1]
Filtro7

# %%
#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('¿Ha participado en algún plan de colaboración con otras tiendas o empresas? \n(por ejemplo, esfuerzos conjuntos de marketing, compras al por mayor, servicios de entrega compartidos)')
Filtro7_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro7_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')

# %% [markdown]
# Tabla 8??????????

# %%
#Analizar categorias de una columna
riesgo_categorias = categoricas.groupby(['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'])['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].count()
riesgo_categorias
# Out:
# ¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)
# 10                                                 51
# Aumento de costos                                   1
# Aumento de precios                                  1
# Capital                                             1
# Competencia                                         2
#                                                    ..
# no son tan constantes                               1
# nunca ha intentado establecer una colaboración      1
# otros                                               1
# poca publicidad                                     1
# ventas bajas                                        1
# Name: ¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan), Length: 206, dtype: int64

# %%
#Sustituyo los strings Atraso, Cancelado y Fraude por la constante "0"
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('Aumento de precios', 'Aumento de costos')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('Ninguna', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('No aplica', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('Na', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('No', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('Ninguno se ha visto necesario', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('Ninguno hay interés', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('Ninguno barrera', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('nunca ha intentado establecer una colaboración', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('no se sabe', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('no quieren', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('no hemos tenido colaboración', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('10', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('ninguno', '')
categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'].str.replace('Ninguno', '')

# %%
h=categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)']
h
# Out:
# 0              Dificultad para encontrar socios adecuados
# 1                     Problemas de confianza y fiabilidad
# 2       Complejidades jurídicas o contractuales, Probl...
# 3       Problemas de confianza y fiabilidad, Contribuc...
# 4                     Problemas de confianza y fiabilidad
#                               ...
# 1161    Dificultad para encontrar socios adecuados, Co...
# 1162             Problemas de comunicación y coordinación
# 1163    Dificultad para encontrar socios adecuados, Pr...
# 1164    Dificultad para encontrar socios adecuados, Pr...
# 1165           Dificultad para encontrar socios adecuados
# Name: ¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan), Length: 1166, dtype: object

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table8= freq_tbl(categoricas['¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)'])
table8

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro8= table8[table8['frequency']>10]
Filtro8

# %%
#Ajusto el indice de mi dataframe
Filtro8_index= Filtro8.set_index('¿Qué retos o barreras ha encontrado al intentar establecer o mantener esquemas de colaboración? (Seleccione todos los que procedan)')
Filtro8_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro8_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro8_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')

# %% [markdown]
# Tabla 9

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table9= freq_tbl(categoricas['En los últimos seis meses ¿ha implementado alguna tecnología digital en su negocio?'])
table9

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro9= table9[table9['frequency']>1]
Filtro9

# %%
#Ajusto el indice de mi dataframe
Filtro9_index= Filtro9.set_index('En los últimos seis meses ¿ha implementado alguna tecnología digital en su negocio?')
Filtro9_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro9_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')

# %% [markdown]
# Tabla 10

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table10= freq_tbl(categoricas['¿Qué factores influyeron o influirían en su decisión de adoptar tecnología en su tienda? (Seleccione todos los que procedan)'])
table10

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro10= table10[table10['frequency']>15]
Filtro10

# %%
#Ajusto el indice de mi dataframe
Filtro10_index= Filtro10.set_index('¿Qué factores influyeron o influirían en su decisión de adoptar tecnología en su tienda? (Seleccione todos los que procedan)')
Filtro10_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro10_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro10_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Tabla 11

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table11= freq_tbl(categoricas['¿A través de cuáles de los siguientes medios se comunicas con los proveedores?'])
table11

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro11= table11[table11['frequency']>10]
Filtro11

# %%
#Ajusto el indice de mi dataframe
Filtro11_index= Filtro11.set_index('¿A través de cuáles de los siguientes medios se comunicas con los proveedores?')
Filtro11_index

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro11_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=False, autopct="%0.1f %%")

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro11_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Tabla 12

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table12= freq_tbl(categoricas['¿Cuántos clientes, en promedio, recibe en un día entre semana?'])
table12
# Out:
# 'No categorical variables to analyze.'

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro12= table12[table12['frequency']>10]
Filtro12

# %%
#Ajusto el indice de mi dataframe
Filtro12_index= Filtro11.set_index('¿Cuántos clientes, en promedio, recibe en un día entre semana?')
Filtro12_index
